# %% [markdown]
# # GSM8K GSPO training on Colab
#
# This notebook runs `RL_GRPO_train/configs/qwen25_3b_sft_gspo.yaml`. The YAML is kept identical to the GRPO baseline except for run naming and GSPO's sequence-level importance sampling fields.

# %%
# !nvidia-smi
# Out:
# Mon May  4 23:57:43 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA H100 80GB HBM3          Off |   00000000:04:00.0 Off |                    0 |
# | N/A   33C    P0             69W /  700W |       0MiB /  81559MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path
import os

candidates = [
    Path('/content/drive/MyDrive/HPML_project'),
    Path('/content/drive/MyDrive/HPML_project/project'),
    Path.cwd(),
]
PROJECT_DIR = next((p for p in candidates if (p / 'RL_GRPO_train').exists() and (p / 'RL_common').exists()), None)
if PROJECT_DIR is None:
    raise FileNotFoundError('Cannot find project root. Mount Drive or edit PROJECT_DIR manually.')

os.chdir(PROJECT_DIR)
print('PROJECT_DIR =', PROJECT_DIR)
# !pwd
# Out:
# PROJECT_DIR = /content/drive/MyDrive/HPML_project
# /content/drive/MyDrive/HPML_project

# %% [markdown]
# ## Tokens and SwanLab

# %%
import getpass
import os

USE_COLAB_SECRETS = True

if USE_COLAB_SECRETS:
    from google.colab import userdata
    for key in ['HF_TOKEN', 'SWANLAB_API_KEY']:
        value = userdata.get(key)
        if value:
            os.environ[key] = value
else:
    for key in ['HF_TOKEN', 'SWANLAB_API_KEY']:
        if not os.environ.get(key):
            value = getpass.getpass(f'{key} (press Enter to skip): ')
            if value:
                os.environ[key] = value

os.environ.setdefault('SWANLAB_PROJECT', 'gsm8k-grpo')

if os.environ.get('HF_TOKEN'):
    from huggingface_hub import login
    login(token=os.environ['HF_TOKEN'], add_to_git_credential=False)

print('SWANLAB_PROJECT =', os.environ.get('SWANLAB_PROJECT'))
print('HF_TOKEN set =', bool(os.environ.get('HF_TOKEN')))
print('SWANLAB_API_KEY set =', bool(os.environ.get('SWANLAB_API_KEY')))
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# SWANLAB_PROJECT = gsm8k-grpo
# HF_TOKEN set = True
# SWANLAB_API_KEY set = True

# %% [markdown]
# ## Install dependencies

# %%
# !pip uninstall -y torchao
# !pip install -q -U "trl[vllm]>=0.29.0" "accelerate>=1.4.0" swanlab bitsandbytes sentencepiece
# !pip install -q -e RL_common

import torch
import trl
import vllm
import accelerate

print('torch =', torch.__version__)
print('trl =', trl.__version__)
print('vllm import ok')
print('cuda available =', torch.cuda.is_available())
if torch.cuda.is_available():
    print('gpu =', torch.cuda.get_device_name(0))
# Out:
# Found existing installation: torchao 0.10.0
# Uninstalling torchao-0.10.0:
#   Successfully uninstalled torchao-0.10.0
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.9/87.9 kB 11.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.6/721.6 kB 28.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 371.2/371.2 kB 37.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 46.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.0/529.0 kB 50.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.1/161.1 kB 21.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 433.2/433.2 MB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.6/192.6 kB 21.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 152.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 14.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 147.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 118.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 85.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 162.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 54.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 699.6/699.6 kB 57.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 34.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 170.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.4/121.4 kB 15.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 103.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 MB 36.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 79.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 108.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.1/72.1 kB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.2/180.2 kB 22.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.6/231.6 kB 30.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 53.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.8/260.8 kB 29.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 MB 61.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.0/388.0 kB 42.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 456.5/456.5 kB 48.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.7/149.7 kB 19.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.0/225.0 kB 27.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 23.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 129.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.4/819.4 kB 73.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 67.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.7/320.7 kB 35.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.8/897.8 kB 72.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 36.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 141.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 959.8/959.8 kB 79.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.41.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.41.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.41.1 which is incompatible.
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for rl-common (pyproject.toml) ... done
# torch = 2.10.0+cu128
# trl = 1.3.0
# vllm import ok
# cuda available = True
# gpu = NVIDIA H100 80GB HBM3

# %% [markdown]
# ## Validate GSPO config

# %%
import inspect
import yaml
from trl import GRPOConfig

BASE_CONFIG = PROJECT_DIR / 'RL_GRPO_train/configs/qwen25_3b_sft_grpo.yaml'
ACTIVE_CONFIG = PROJECT_DIR / 'RL_GRPO_train/configs/qwen25_3b_sft_gspo.yaml'

ALLOWED_GSPO_DIFFS = {
    ('run', 'name'),
    ('grpo', 'run_name'),
    ('grpo', 'loss_type'),
    ('grpo', 'importance_sampling_level'),
}

def changed_paths(left, right, prefix=()):
    if isinstance(left, dict) and isinstance(right, dict):
        keys = set(left) | set(right)
        for key in sorted(keys):
            yield from changed_paths(left.get(key), right.get(key), prefix + (key,))
    elif left != right:
        yield prefix

base_cfg = yaml.safe_load(BASE_CONFIG.read_text(encoding='utf-8'))
cfg = yaml.safe_load(ACTIVE_CONFIG.read_text(encoding='utf-8'))

unexpected = sorted(set(changed_paths(base_cfg, cfg)) - ALLOWED_GSPO_DIFFS)
if unexpected:
    raise AssertionError(f'Unexpected non-GSPO config changes: {unexpected}')

signature = inspect.signature(GRPOConfig.__init__)
accepts_kwargs = any(param.kind == inspect.Parameter.VAR_KEYWORD for param in signature.parameters.values())
required_args = {'loss_type', 'importance_sampling_level'}
missing_args = set() if accepts_kwargs else required_args - set(signature.parameters)
if missing_args:
    raise RuntimeError(f'The installed TRL GRPOConfig does not support GSPO fields: {sorted(missing_args)}')

print('ACTIVE_CONFIG =', ACTIVE_CONFIG)
print(ACTIVE_CONFIG.read_text(encoding='utf-8'))
# Out:
# ACTIVE_CONFIG = /content/drive/MyDrive/HPML_project/RL_GRPO_train/configs/qwen25_3b_sft_gspo.yaml
# run:
#   name: qwen25_3b_instruct_sft_gspo_g{grpo.num_generations}_train{train_dataset.limit}
#   output_root: RL_GRPO_train/outputs
#
# model:
#   base_model_name_or_path: Qwen/Qwen2.5-3B-Instruct
#   adapter_path: SFT_train/outputs/qwen25_3b_gsm8k_lora_sft_full
#   tokenizer_name_or_path: Qwen/Qwen2.5-3B-Instruct
#   trust_remote_code: true
#   prompt_template: qwen_chat
#   system_prompt: ""
#   include_empty_system: false
#   dtype: bf16
#   device_map:
#   load_in_4bit: false
#   is_trainable_adapter: true
#
# train_dataset:
#   kind: sft_train
#   name: openai/gsm8k
#   config: main
#   path: SFT_train/data/gsm8k_sft_train.json
#   limit:
#
# eval_dataset:
#   kind: sft_val
#   name: openai/gsm8k
#   config: main
#   path: SFT_train/data/gsm8k_sft_val.json
#   limit: 725
#
# final_eval_dataset:
#   kind: gsm8k_test
#   name: openai/gsm8k
#   config: main
#   start_index: 0
#   limit:
#
# reward:
#   answer_correct: 1.0
#   answer_incorrect: 0.0
#   format_reward: 0.02
#   parse_fail_penalty: -0.1
#   length_penalty: -0.1
#   min_completion_tokens: 20
#   max_completion_tokens: 130
#
# eval:
#   every_steps: 20
#   batch_size: 370
#   max_prompt_length: 512
#   max_new_tokens: 256
#   metric_for_best: exact_match
#
# grpo:
#   per_device_train_batch_size: 32
#   num_generations: 16
#   generation_batch_size: 512
#   gradient_accumulation_steps: 2
#   temperature: 1.0
#   top_p: 0.95
#   learning_rate: 2.0e-6
#   lr_scheduler_type: cosine
#   max_prompt_length: 512
#   max_completion_length: 256
#   max_steps: 1000
#   warmup_ratio: 0.03
#   weight_decay: 0.0
#   max_grad_norm: 1.0
#   beta: 0.001
#   logging_steps: 3
#   save_strategy: "no"
#   eval_strategy: "no"
#   remove_unused_columns: false
#   gradient_checkpointing: true
#   bf16: true
#   report_to: "swanlab"
#   run_name: qwen25_3b_instruct_sft_gspo_g{grpo.num_generations}
#   use_vllm: true
#   vllm_mode: colocate
#   loss_type: grpo
#   importance_sampling_level: sequence
#   seed: 42
#   data_seed: 42

# %% [markdown]
# ## Train

# %%
# !accelerate launch --num_processes 1 RL_GRPO_train/train_grpo.py --config "{ACTIVE_CONFIG}"
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 2026-05-05 00:01:44.961269: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-05 00:01:45.012179: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# tokenizer_config.json: 7.30kB [00:00, 15.7MB/s]
# vocab.json: 2.78MB [00:00, 40.0MB/s]
# merges.txt: 1.67MB [00:00, 11.3MB/s]
# tokenizer.json: 7.03MB [00:00, 220MB/s]
# config.json: 100% 661/661 [00:00<00:00, 5.51MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 35.6kB [00:00, 145MB/s]
# Fetching 2 files:   0% 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0% 0.00/2.20G [00:00<?, ?B/s]
#
# model-00001-of-00002.safetensors:   0% 0.00/3.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0% 0.00/2.20G [00:00<?, ?B/s]
#
# model-00001-of-00002.safetensors:   0% 0.00/3.97G [00:00<?, ?B/s]
#
# model-00001-of-00002.safetensors:   0% 0.00/3.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0% 0.00/2.20G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   1% 25.1M/2.20G [00:00<00:17, 126MB/s]
#
# model-00001-of-00002.safetensors:   0% 20.3k/3.97G [00:00<10:51:26, 102kB/s]
# model-00002-of-00002.safetensors:   4% 90.8M/2.20G [00:01<00:13, 154MB/s]
# model-00002-of-00002.safetensors:  12% 256M/2.20G [00:01<00:06, 287MB/s]
# model-00002-of-00002.safetensors:  13% 292M/2.20G [00:01<00:07, 258MB/s]
# model-00002-of-00002.safetensors:  16% 359M/2.20G [00:01<00:06, 280MB/s]
#
# model-00001-of-00002.safetensors:   7% 268M/3.97G [00:01<00:18, 200MB/s]
# model-00002-of-00002.safetensors:  19% 426M/2.20G [00:02<00:07, 230MB/s]
# model-00002-of-00002.safetensors:  23% 508M/2.20G [00:02<00:06, 273MB/s]
# model-00002-of-00002.safetensors:  32% 694M/2.20G [00:02<00:03, 441MB/s]
# model-00002-of-00002.safetensors:  38% 828M/2.20G [00:02<00:02, 502MB/s]
# model-00002-of-00002.safetensors:  44% 970M/2.20G [00:03<00:02, 560MB/s]
# model-00002-of-00002.safetensors:  47% 1.03G/2.20G [00:03<00:02, 485MB/s]
# model-00002-of-00002.safetensors:  53% 1.16G/2.20G [00:03<00:01, 538MB/s]
# model-00002-of-00002.safetensors:  59% 1.30G/2.20G [00:03<00:01, 577MB/s]
#
# model-00001-of-00002.safetensors:  23% 912M/3.97G [00:03<00:10, 304MB/s]
#
# model-00001-of-00002.safetensors:  31% 1.24G/3.97G [00:03<00:06, 429MB/s]
# model-00002-of-00002.safetensors:  65% 1.43G/2.20G [00:03<00:01, 606MB/s]
#
# model-00001-of-00002.safetensors:  40% 1.58G/3.97G [00:04<00:04, 580MB/s]
# model-00002-of-00002.safetensors:  80% 1.77G/2.20G [00:04<00:00, 921MB/s]
#
# model-00001-of-00002.safetensors:  45% 1.78G/3.97G [00:04<00:03, 642MB/s]
# model-00002-of-00002.safetensors:  93% 2.05G/2.20G [00:05<00:00, 487MB/s]
#
# model-00001-of-00002.safetensors:  51% 2.01G/3.97G [00:05<00:04, 482MB/s]
# model-00002-of-00002.safetensors: 100% 2.20G/2.20G [00:05<00:00, 403MB/s]
#
# model-00002-of-00002.safetensors: 100% 2.20G/2.20G [00:06<00:00, 326MB/s]
#
#
# model-00001-of-00002.safetensors:  70% 2.78G/3.97G [00:07<00:02, 441MB/s]
#
# model-00001-of-00002.safetensors:  79% 3.12G/3.97G [00:07<00:01, 577MB/s]
#
# model-00001-of-00002.safetensors:  88% 3.50G/3.97G [00:07<00:00, 750MB/s]
#
# model-00001-of-00002.safetensors:  96% 3.81G/3.97G [00:07<00:00, 883MB/s]
#
# model-00001-of-00002.safetensors: 100% 3.97G/3.97G [00:08<00:00, 489MB/s]
# Fetching 2 files: 100% 2/2 [00:08<00:00,  4.21s/it]
# Loading checkpoint shards: 100% 2/2 [00:00<00:00, 53.60it/s]
# generation_config.json: 100% 242/242 [00:00<00:00, 2.02MB/s]
# README.md: 7.93kB [00:00, 28.4MB/s]
# main/train-00000-of-00001.parquet: 100% 2.31M/2.31M [00:00<00:00, 3.80MB/s]
# main/test-00000-of-00001.parquet: 100% 419k/419k [00:00<00:00, 2.01MB/s]
# Generating train split: 100% 7473/7473 [00:00<00:00, 450338.84 examples/s]
# Generating test split: 100% 1319/1319 [00:00<00:00, 318093.78 examples/s]
# Ignoring unsupported GRPOConfig keys: ['max_prompt_length']
# <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.cudart module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.runtime module instead.
# <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.nvrtc module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.nvrtc module instead.
# Loading safetensors checkpoint shards: 100% 2/2 [00:01<00:00,  1.82it/s]
# 2026-05-05 00:03:24,077 - INFO - autotuner.py:262 - flashinfer.jit: [Autotuner]: Autotuning process starts ...
# 2026-05-05 00:03:24,088 - INFO - autotuner.py:268 - flashinfer.jit: [Autotuner]: Autotuning process ends
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE): 100% 51/51 [00:02<00:00, 22.93it/s]
# Capturing CUDA graphs (decode, FULL): 100% 51/51 [00:01<00:00, 40.55it/s]
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
# ⠴ Waiting for the swanlab cloud response.
# ⠸ Creating experiment...
# swanlab: Tracking run with swanlab version 0.7.16
# swanlab: Run data will be saved locally in
# /content/drive/MyDrive/HPML_project/swanlog/run-20260505_000332-k4pn6ix5vuj10x0n
# pedwv
# swanlab: 👋 Hi jerryjsjsj,welcome to swanlab!
# swanlab: Syncing run qwen25_3b_instruct_sft_gspo_g16 to the cloud
# swanlab: 🏠 View project at https://swanlab.cn/@jerryjsjsj/gsm8k-grpo
# swanlab: 🚀 View run at
# https://swanlab.cn/@jerryjsjsj/gsm8k-grpo/runs/k4pn6ix5vuj10x0npedwv
#   0% 0/1000 [00:00<?, ?it/s]Could not estimate the number of tokens of the input, floating-point operations will not be computed
# {'loss': -0.0066, 'grad_norm': 0.09347208589315414, 'learning_rate': 1.3333333333333334e-07, 'completions/mean_length': 99.138671875, 'completions/clipped_ratio': 0.0, 'reward': 0.7471092939376831, 'reward_std': 0.45153820514678955, 'frac_reward_zero_std': 0.28125, 'answer_exact_match': 0.740234375, 'format_exact_rate': 0.998046875, 'length_penalty_rate': 0.130859375, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.020228829234838486, 'sampling/importance_sampling_ratio/mean': 0.34061869978904724, 'kl': 0.00044178606185596436, 'entropy': 0.3541993151108424, 'clip_ratio/region_mean': 0.0, 'epoch': 0.0}
# {'loss': -0.0401, 'grad_norm': 0.10395407676696777, 'learning_rate': 3.333333333333333e-07, 'kl': 0.0004861376849779238, 'entropy': 0.341261883576711, 'clip_ratio/region_mean': 0.0, 'epoch': 0.0}
# {'loss': -0.0036, 'grad_norm': 0.11243129521608353, 'learning_rate': 5.333333333333333e-07, 'kl': 0.0003874793862147878, 'entropy': 0.3072614719470342, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 90.205078125, 'completions/clipped_ratio': 0.0, 'reward': 0.8494921326637268, 'reward_std': 0.3726056218147278, 'frac_reward_zero_std': 0.34375, 'answer_exact_match': 0.837890625, 'format_exact_rate': 1.0, 'length_penalty_rate': 0.083984375, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.018168237060308456, 'sampling/importance_sampling_ratio/mean': 0.42934125661849976, 'epoch': 0.01}
# {'loss': 0.0136, 'grad_norm': 0.32286468148231506, 'learning_rate': 7.333333333333332e-07, 'kl': 0.000368428387446329, 'entropy': 0.2811679194370906, 'clip_ratio/region_mean': 0.0, 'epoch': 0.01}
# {'loss': -0.0423, 'grad_norm': 0.15972329676151276, 'learning_rate': 9.333333333333333e-07, 'kl': 0.0004436555997623752, 'entropy': 0.30702583988507587, 'clip_ratio/region_mean': 0.0, 'epoch': 0.01}
# {'loss': -0.0353, 'grad_norm': 0.10274388641119003, 'learning_rate': 1.1333333333333332e-06, 'kl': 0.00042114151680531603, 'entropy': 0.2786942422389984, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 96.994140625, 'completions/clipped_ratio': 0.0, 'reward': 0.7955077886581421, 'reward_std': 0.41773703694343567, 'frac_reward_zero_std': 0.4375, 'answer_exact_match': 0.7890625, 'format_exact_rate': 0.99609375, 'length_penalty_rate': 0.134765625, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.017461435869336128, 'sampling/importance_sampling_ratio/mean': 0.42938870191574097, 'epoch': 0.01}
#   2% 19/1000 [01:29<1:03:02,  3.86s/it]
# Greedy eval step 20:   0% 0/2 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#
# Greedy eval step 20:  50% 1/2 [00:18<00:18, 18.16s/it]
# Greedy eval step 20: 100% 2/2 [00:43<00:00, 21.66s/it]
# {'loss': -0.0149, 'grad_norm': 0.07027118653059006, 'learning_rate': 1.3333333333333332e-06, 'kl': 0.00037042019054448855, 'entropy': 0.26955625663201016, 'clip_ratio/region_mean': 0.0, 'epoch': 0.01}
# {'loss': 0.0029, 'grad_norm': 0.059982191771268845, 'learning_rate': 1.5333333333333334e-06, 'kl': 0.000456398901102754, 'entropy': 0.27891021966934204, 'clip_ratio/region_mean': 0.0, 'epoch': 0.01}
# {'loss': -0.0178, 'grad_norm': 0.0974004939198494, 'learning_rate': 1.7333333333333334e-06, 'completions/mean_length': 93.908203125, 'completions/clipped_ratio': 0.0, 'reward': 0.8392578363418579, 'reward_std': 0.3849235773086548, 'frac_reward_zero_std': 0.3125, 'answer_exact_match': 0.830078125, 'format_exact_rate': 0.99609375, 'length_penalty_rate': 0.107421875, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.017527563497424126, 'sampling/importance_sampling_ratio/mean': 0.4096095561981201, 'kl': 0.00047633640254692483, 'entropy': 0.2786661684513092, 'clip_ratio/region_mean': 0.0, 'epoch': 0.02}
# {'loss': -0.0052, 'grad_norm': 0.10260327160358429, 'learning_rate': 1.933333333333333e-06, 'kl': 0.0005153735110070556, 'entropy': 0.27452267458041507, 'clip_ratio/region_mean': 0.0, 'epoch': 0.02}
# {'loss': -0.0242, 'grad_norm': 0.09199148416519165, 'learning_rate': 1.999979021001399e-06, 'kl': 0.0006557448262659212, 'entropy': 0.28054921825726825, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 100.9609375, 'completions/clipped_ratio': 0.0, 'reward': 0.7953906059265137, 'reward_std': 0.42123183608055115, 'frac_reward_zero_std': 0.34375, 'answer_exact_match': 0.7890625, 'format_exact_rate': 1.0, 'length_penalty_rate': 0.13671875, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.01795637607574463, 'sampling/importance_sampling_ratio/mean': 0.4102957248687744, 'epoch': 0.02}
# {'loss': -0.0479, 'grad_norm': 0.10705190896987915, 'learning_rate': 1.999868883665632e-06, 'kl': 0.000685741319709147, 'entropy': 0.30273377895355225, 'clip_ratio/region_mean': 0.0, 'epoch': 0.02}
# {'loss': 0.0008, 'grad_norm': 0.10361719876527786, 'learning_rate': 1.99966435362682e-06, 'kl': 0.0007750745474671324, 'entropy': 0.31090327600638074, 'clip_ratio/region_mean': 0.0, 'epoch': 0.02}
#   4% 39/1000 [03:30<48:18,  3.02s/it]
# Greedy eval step 40:   0% 0/2 [00:00<?, ?it/s]
# Greedy eval step 40:  50% 1/2 [00:18<00:18, 18.38s/it]
# Greedy eval step 40: 100% 2/2 [00:43<00:00, 21.81s/it]
# {'loss': -0.0412, 'grad_norm': 0.07748617231845856, 'learning_rate': 1.9993654501936378e-06, 'kl': 0.0009025144778812925, 'entropy': 0.30776792764663696, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 99.919921875, 'completions/clipped_ratio': 0.001953125, 'reward': 0.7988671660423279, 'reward_std': 0.41221025586128235, 'frac_reward_zero_std': 0.3125, 'answer_exact_match': 0.791015625, 'format_exact_rate': 0.998046875, 'length_penalty_rate': 0.12109375, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.01779000833630562, 'sampling/importance_sampling_ratio/mean': 0.3803181052207947, 'epoch': 0.03}
# {'loss': -0.0113, 'grad_norm': 0.07858671247959137, 'learning_rate': 1.9989722015840878e-06, 'kl': 0.001088134430271263, 'entropy': 0.28802214562892914, 'clip_ratio/region_mean': 0.0, 'epoch': 0.03}
# {'loss': -0.0208, 'grad_norm': 0.08242220431566238, 'learning_rate': 1.9984846449228367e-06, 'kl': 0.0012253864745919902, 'entropy': 0.2889684389034907, 'clip_ratio/region_mean': 0.0, 'epoch': 0.03}
# {'loss': -0.0496, 'grad_norm': 0.10772949457168579, 'learning_rate': 1.9979028262377116e-06, 'completions/mean_length': 97.1015625, 'completions/clipped_ratio': 0.0, 'reward': 0.8303515315055847, 'reward_std': 0.38942763209342957, 'frac_reward_zero_std': 0.15625, 'answer_exact_match': 0.8203125, 'format_exact_rate': 1.0, 'length_penalty_rate': 0.099609375, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.01676357351243496, 'sampling/importance_sampling_ratio/mean': 0.41078633069992065, 'kl': 0.0012749116867780685, 'entropy': 0.25081397593021393, 'clip_ratio/region_mean': 0.0, 'epoch': 0.03}
# {'loss': 0.0098, 'grad_norm': 0.24065862596035004, 'learning_rate': 1.9972268004553517e-06, 'kl': 0.0016360287166511018, 'entropy': 0.28851623833179474, 'clip_ratio/region_mean': 0.0, 'epoch': 0.03}
# {'loss': -0.0286, 'grad_norm': 0.06628312915563583, 'learning_rate': 1.996456631396026e-06, 'kl': 0.0018350286603284378, 'entropy': 0.2737082590659459, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 92.09765625, 'completions/clipped_ratio': 0.0, 'reward': 0.8207812309265137, 'reward_std': 0.40102532505989075, 'frac_reward_zero_std': 0.46875, 'answer_exact_match': 0.810546875, 'format_exact_rate': 1.0, 'length_penalty_rate': 0.09765625, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.016763174906373024, 'sampling/importance_sampling_ratio/mean': 0.45895981788635254, 'epoch': 0.03}
#   6% 59/1000 [05:47<1:12:11,  4.60s/it]
# Greedy eval step 60:   0% 0/2 [00:00<?, ?it/s]
# Greedy eval step 60:  50% 1/2 [00:21<00:21, 21.87s/it]
# Greedy eval step 60: 100% 2/2 [00:43<00:00, 21.56s/it]
# {'loss': 0.0186, 'grad_norm': 0.07106534391641617, 'learning_rate': 1.995592391767608e-06, 'kl': 0.0018425635644234717, 'entropy': 0.25386155148347217, 'clip_ratio/region_mean': 0.0, 'epoch': 0.04}
# {'loss': 0.0054, 'grad_norm': 0.11937645077705383, 'learning_rate': 1.9946341631587084e-06, 'kl': 0.002017605428894361, 'entropy': 0.28667305161555606, 'clip_ratio/region_mean': 0.0, 'epoch': 0.04}
# {'loss': -0.0459, 'grad_norm': 0.11435171961784363, 'learning_rate': 1.9935820360309776e-06, 'kl': 0.0022929642194261155, 'entropy': 0.2992568264404933, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 96.611328125, 'completions/clipped_ratio': 0.0, 'reward': 0.8191796541213989, 'reward_std': 0.4051431715488434, 'frac_reward_zero_std': 0.40625, 'answer_exact_match': 0.80859375, 'format_exact_rate': 0.998046875, 'length_penalty_rate': 0.09375, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.017824430018663406, 'sampling/importance_sampling_ratio/mean': 0.4325907826423645, 'epoch': 0.04}
# {'loss': -0.0121, 'grad_norm': 0.18897312879562378, 'learning_rate': 1.992436109710562e-06, 'kl': 0.0027641906635835767, 'entropy': 0.3045852333307266, 'clip_ratio/region_mean': 0.0, 'epoch': 0.04}
# {'loss': 0.0123, 'grad_norm': 0.08764022588729858, 'learning_rate': 1.9911964923787293e-06, 'kl': 0.0028389683769394955, 'entropy': 0.2810455660025279, 'clip_ratio/region_mean': 0.0, 'epoch': 0.04}
# {'loss': -0.0206, 'grad_norm': 0.06746161729097366, 'learning_rate': 1.989863301061654e-06, 'completions/mean_length': 102.431640625, 'completions/clipped_ratio': 0.0, 'reward': 0.7144531011581421, 'reward_std': 0.4687599539756775, 'frac_reward_zero_std': 0.4375, 'answer_exact_match': 0.7109375, 'format_exact_rate': 0.99609375, 'length_penalty_rate': 0.1640625, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.018915338441729546, 'sampling/importance_sampling_ratio/mean': 0.3767877519130707, 'kl': 0.0032015311686942973, 'entropy': 0.31478480994701385, 'clip_ratio/region_mean': 0.0, 'epoch': 0.05}
# {'loss': 0.0035, 'grad_norm': 0.19994747638702393, 'learning_rate': 1.9884366616193706e-06, 'kl': 0.0034247024450451136, 'entropy': 0.31608956555525464, 'clip_ratio/region_mean': 0.0, 'epoch': 0.05}
#   8% 79/1000 [07:53<50:01,  3.26s/it]
# Greedy eval step 80:   0% 0/2 [00:00<?, ?it/s]
# Greedy eval step 80:  50% 1/2 [00:22<00:22, 22.07s/it]
# Greedy eval step 80: 100% 2/2 [00:46<00:00, 23.49s/it]
# {'loss': -0.0202, 'grad_norm': 0.06639336794614792, 'learning_rate': 1.9869167087338906e-06, 'kl': 0.0034466146025806665, 'entropy': 0.3055701454480489, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 92.587890625, 'completions/clipped_ratio': 0.0, 'reward': 0.8465234041213989, 'reward_std': 0.3773742914199829, 'frac_reward_zero_std': 0.375, 'answer_exact_match': 0.837890625, 'format_exact_rate': 0.998046875, 'length_penalty_rate': 0.11328125, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.017841549590229988, 'sampling/importance_sampling_ratio/mean': 0.4197150468826294, 'epoch': 0.05}
# {'loss': -0.0023, 'grad_norm': 0.3057013750076294, 'learning_rate': 1.9853035858964904e-06, 'kl': 0.0032377823954448104, 'entropy': 0.2704330235719681, 'clip_ratio/region_mean': 0.0, 'epoch': 0.05}
# {'loss': -0.0101, 'grad_norm': 0.0701616182923317, 'learning_rate': 1.983597445394162e-06, 'kl': 0.004226536101972063, 'entropy': 0.2994473874568939, 'clip_ratio/region_mean': 0.0, 'epoch': 0.05}
# {'loss': -0.0028, 'grad_norm': 0.21258163452148438, 'learning_rate': 1.9817984482952373e-06, 'kl': 0.0037379193818196654, 'entropy': 0.29112857083479565, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 96.93359375, 'completions/clipped_ratio': 0.0, 'reward': 0.8095702528953552, 'reward_std': 0.40779849886894226, 'frac_reward_zero_std': 0.375, 'answer_exact_match': 0.80078125, 'format_exact_rate': 0.99609375, 'length_penalty_rate': 0.111328125, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.017637096345424652, 'sampling/importance_sampling_ratio/mean': 0.40275096893310547, 'epoch': 0.06}
# {'loss': -0.0009, 'grad_norm': 0.08205347508192062, 'learning_rate': 1.9799067644341843e-06, 'kl': 0.003640550382745763, 'entropy': 0.2849687909086545, 'clip_ratio/region_mean': 0.0, 'epoch': 0.06}
# {'loss': -0.0378, 'grad_norm': 0.13039889931678772, 'learning_rate': 1.9779225723955706e-06, 'kl': 0.004280405157866578, 'entropy': 0.26723800351222354, 'clip_ratio/region_mean': 0.0, 'epoch': 0.06}
# {'loss': -0.0308, 'grad_norm': 0.11381689459085464, 'learning_rate': 1.9758460594972068e-06, 'completions/mean_length': 94.404296875, 'completions/clipped_ratio': 0.0, 'reward': 0.8801171779632568, 'reward_std': 0.3437504470348358, 'frac_reward_zero_std': 0.40625, 'answer_exact_match': 0.87109375, 'format_exact_rate': 0.998046875, 'length_penalty_rate': 0.109375, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.016031641513109207, 'sampling/importance_sampling_ratio/mean': 0.47451531887054443, 'kl': 0.004024112907548745, 'entropy': 0.25102000186840695, 'clip_ratio/region_mean': 0.0, 'epoch': 0.06}
#  10% 99/1000 [10:07<1:03:59,  4.26s/it]
# Greedy eval step 100:   0% 0/2 [00:00<?, ?it/s]
# Greedy eval step 100:  50% 1/2 [00:20<00:20, 20.89s/it]
# Greedy eval step 100: 100% 2/2 [00:46<00:00, 23.01s/it]
# {'loss': -0.0213, 'grad_norm': 0.060272686183452606, 'learning_rate': 1.973677421772461e-06, 'kl': 0.004711727689330776, 'entropy': 0.2366145427028338, 'clip_ratio/region_mean': 0.0, 'epoch': 0.06}
# {'loss': 0.0052, 'grad_norm': 0.0838288739323616, 'learning_rate': 1.971416863951754e-06, 'kl': 0.00536167078341047, 'entropy': 0.24481702347596487, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 95.23046875, 'completions/clipped_ratio': 0.0, 'reward': 0.8701562285423279, 'reward_std': 0.3547673225402832, 'frac_reward_zero_std': 0.5625, 'answer_exact_match': 0.861328125, 'format_exact_rate': 0.998046875, 'length_penalty_rate': 0.111328125, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.015162522904574871, 'sampling/importance_sampling_ratio/mean': 0.47207629680633545, 'epoch': 0.06}
# {'loss': 0.009, 'grad_norm': 0.08961273729801178, 'learning_rate': 1.9690645994432303e-06, 'kl': 0.004187881403292219, 'entropy': 0.23776167631149292, 'clip_ratio/region_mean': 0.0, 'epoch': 0.07}
# {'loss': -0.0281, 'grad_norm': 0.04958464577794075, 'learning_rate': 1.966620850312611e-06, 'kl': 0.004724448701987664, 'entropy': 0.2331058382987976, 'clip_ratio/region_mean': 0.0, 'epoch': 0.07}
# {'loss': -0.0016, 'grad_norm': 0.12462344020605087, 'learning_rate': 1.9640858472622316e-06, 'kl': 0.005535295155520241, 'entropy': 0.23761228720347086, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 96.2734375, 'completions/clipped_ratio': 0.0, 'reward': 0.8598437309265137, 'reward_std': 0.36470288038253784, 'frac_reward_zero_std': 0.46875, 'answer_exact_match': 0.857421875, 'format_exact_rate': 1.0, 'length_penalty_rate': 0.17578125, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.015756670385599136, 'sampling/importance_sampling_ratio/mean': 0.4849388599395752, 'epoch': 0.07}
# {'loss': -0.0247, 'grad_norm': 0.0492536798119545, 'learning_rate': 1.96145982960926e-06, 'kl': 0.005992236469561855, 'entropy': 0.2509403998653094, 'clip_ratio/region_mean': 0.0, 'epoch': 0.07}
#  12% 119/1000 [12:08<42:11,  2.87s/it]
# Greedy eval step 120:   0% 0/2 [00:00<?, ?it/s]
# Greedy eval step 120:  50% 1/2 [00:20<00:20, 20.57s/it]
# Greedy eval step 120: 100% 2/2 [00:45<00:00, 22.86s/it]
# {'loss': -0.0281, 'grad_norm': 0.04187453165650368, 'learning_rate': 1.9587430452631055e-06, 'kl': 0.006010420465221007, 'entropy': 0.24095535526672998, 'clip_ratio/region_mean': 0.0, 'epoch': 0.07}
# {'loss': -0.0082, 'grad_norm': 0.210596963763237, 'learning_rate': 1.955935750702016e-06, 'completions/mean_length': 92.958984375, 'completions/clipped_ratio': 0.0, 'reward': 0.8164061903953552, 'reward_std': 0.4073353409767151, 'frac_reward_zero_std': 0.40625, 'answer_exact_match': 0.806640625, 'format_exact_rate': 0.99609375, 'length_penalty_rate': 0.1015625, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.01753966696560383, 'sampling/importance_sampling_ratio/mean': 0.45321524143218994, 'kl': 0.006289447502543529, 'entropy': 0.2600102946162224, 'clip_ratio/region_mean': 0.0, 'epoch': 0.08}
# {'loss': -0.0259, 'grad_norm': 0.07781201601028442, 'learning_rate': 1.953038210948861e-06, 'kl': 0.005972940629969041, 'entropy': 0.28601600229740143, 'clip_ratio/region_mean': 0.0, 'epoch': 0.08}
# {'loss': -0.0332, 'grad_norm': 0.050333064049482346, 'learning_rate': 1.9500506995461158e-06, 'kl': 0.006372538860887289, 'entropy': 0.27662206689516705, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 99.98828125, 'completions/clipped_ratio': 0.0, 'reward': 0.7869530916213989, 'reward_std': 0.42538630962371826, 'frac_reward_zero_std': 0.375, 'answer_exact_match': 0.779296875, 'format_exact_rate': 0.998046875, 'length_penalty_rate': 0.123046875, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.017424995079636574, 'sampling/importance_sampling_ratio/mean': 0.41024476289749146, 'epoch': 0.08}
# {'loss': 0.0283, 'grad_norm': 0.14745785295963287, 'learning_rate': 1.946973498530037e-06, 'kl': 0.005936548812314868, 'entropy': 0.27612592031558353, 'clip_ratio/region_mean': 0.0, 'epoch': 0.08}
# {'loss': -0.0398, 'grad_norm': 0.06929481029510498, 'learning_rate': 1.943806898404036e-06, 'kl': 0.0059868621950348215, 'entropy': 0.29015424102544785, 'clip_ratio/region_mean': 0.0, 'epoch': 0.08}
# {'loss': -0.0227, 'grad_norm': 0.11244602501392365, 'learning_rate': 1.940551198111255e-06, 'kl': 0.006185592074568073, 'entropy': 0.24752439806858698, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 103.408203125, 'completions/clipped_ratio': 0.009765625, 'reward': 0.8051562309265137, 'reward_std': 0.41209501028060913, 'frac_reward_zero_std': 0.28125, 'answer_exact_match': 0.80078125, 'format_exact_rate': 0.990234375, 'length_penalty_rate': 0.154296875, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.015759184956550598, 'sampling/importance_sampling_ratio/mean': 0.4484139084815979, 'epoch': 0.08}
#  14% 139/1000 [14:25<1:05:49,  4.59s/it]
# Greedy eval step 140:   0% 0/2 [00:00<?, ?it/s]
# Greedy eval step 140:  50% 1/2 [00:22<00:22, 22.89s/it]
# Greedy eval step 140: 100% 2/2 [00:47<00:00, 23.93s/it]
# {'loss': -0.0322, 'grad_norm': 0.06340194493532181, 'learning_rate': 1.9372067050063438e-06, 'kl': 0.006553394642348091, 'entropy': 0.24288861205180487, 'clip_ratio/region_mean': 0.0, 'epoch': 0.09}
# {'loss': -0.0383, 'grad_norm': 0.1041409969329834, 'learning_rate': 1.9337737348264444e-06, 'kl': 0.006601981896286209, 'entropy': 0.22728940347830454, 'clip_ratio/region_mean': 0.0, 'epoch': 0.09}
# {'loss': -0.0288, 'grad_norm': 0.24647431075572968, 'learning_rate': 1.9302526116613863e-06, 'completions/mean_length': 84.97265625, 'completions/clipped_ratio': 0.0, 'reward': 0.9254686832427979, 'reward_std': 0.2906389832496643, 'frac_reward_zero_std': 0.46875, 'answer_exact_match': 0.908203125, 'format_exact_rate': 1.0, 'length_penalty_rate': 0.02734375, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.015591198578476906, 'sampling/importance_sampling_ratio/mean': 0.507030189037323, 'kl': 0.0074447189302494126, 'entropy': 0.2129486749569575, 'clip_ratio/region_mean': 0.0, 'epoch': 0.09}
# {'loss': -0.0079, 'grad_norm': 0.17221030592918396, 'learning_rate': 1.9266436679230864e-06, 'kl': 0.00910600988815228, 'entropy': 0.22396438320477804, 'clip_ratio/region_mean': 0.0, 'epoch': 0.09}
# {'loss': -0.0275, 'grad_norm': 0.09171046316623688, 'learning_rate': 1.922947244314172e-06, 'kl': 0.008308055733020106, 'entropy': 0.2387183556954066, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 98.427734375, 'completions/clipped_ratio': 0.00390625, 'reward': 0.800976574420929, 'reward_std': 0.4195270538330078, 'frac_reward_zero_std': 0.375, 'answer_exact_match': 0.796875, 'format_exact_rate': 0.99609375, 'length_penalty_rate': 0.158203125, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.017109690234065056, 'sampling/importance_sampling_ratio/mean': 0.4328746795654297, 'epoch': 0.09}
# {'loss': 0.0077, 'grad_norm': 0.10507802665233612, 'learning_rate': 1.919163689795812e-06, 'kl': 0.006803003993506233, 'entropy': 0.25920653343200684, 'clip_ratio/region_mean': 0.0, 'epoch': 0.1}
# {'loss': -0.0011, 'grad_norm': 0.09975884854793549, 'learning_rate': 1.9152933615547795e-06, 'kl': 0.006986136082559824, 'entropy': 0.2671543409427007, 'clip_ratio/region_mean': 0.0, 'epoch': 0.1}
#  16% 159/1000 [16:30<45:03,  3.21s/it]
# Greedy eval step 160:   0% 0/2 [00:00<?, ?it/s]
# Greedy eval step 160:  50% 1/2 [00:18<00:18, 18.85s/it]
# Greedy eval step 160: 100% 2/2 [00:44<00:00, 22.04s/it]
# {'loss': 0.0005, 'grad_norm': 0.17328114807605743, 'learning_rate': 1.9113366249697245e-06, 'kl': 0.007275994246204694, 'entropy': 0.23719622443119684, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 104.640625, 'completions/clipped_ratio': 0.001953125, 'reward': 0.7673827409744263, 'reward_std': 0.42844390869140625, 'frac_reward_zero_std': 0.15625, 'answer_exact_match': 0.767578125, 'format_exact_rate': 0.99609375, 'length_penalty_rate': 0.201171875, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.016529470682144165, 'sampling/importance_sampling_ratio/mean': 0.425845742225647, 'epoch': 0.1}
# {'loss': -0.0178, 'grad_norm': 0.14257663488388062, 'learning_rate': 1.9072938535766863e-06, 'kl': 0.007102134559924404, 'entropy': 0.2620150223374367, 'clip_ratio/region_mean': 0.0, 'epoch': 0.1}
# {'loss': -0.0343, 'grad_norm': 0.16881074011325836, 'learning_rate': 1.9031654290338253e-06, 'kl': 0.0071439119055867195, 'entropy': 0.2711982876062393, 'clip_ratio/region_mean': 0.0, 'epoch': 0.1}
# {'loss': 0.0044, 'grad_norm': 0.08801398426294327, 'learning_rate': 1.8989517410853952e-06, 'completions/mean_length': 98.291015625, 'completions/clipped_ratio': 0.001953125, 'reward': 0.80078125, 'reward_std': 0.41133567690849304, 'frac_reward_zero_std': 0.21875, 'answer_exact_match': 0.79296875, 'format_exact_rate': 0.99609375, 'length_penalty_rate': 0.12109375, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.016977103427052498, 'sampling/importance_sampling_ratio/mean': 0.44130364060401917, 'kl': 0.007890022592619061, 'entropy': 0.2705625270803769, 'clip_ratio/region_mean': 0.0, 'epoch': 0.1}
# {'loss': -0.0346, 'grad_norm': 0.09298303723335266, 'learning_rate': 1.8946531875249493e-06, 'kl': 0.007964392037441334, 'entropy': 0.27298052857319516, 'clip_ratio/region_mean': 0.0, 'epoch': 0.11}
# {'loss': -0.0293, 'grad_norm': 0.07645589113235474, 'learning_rate': 1.890270174157784e-06, 'kl': 0.007818607147783041, 'entropy': 0.26204074422518414, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 88.298828125, 'completions/clipped_ratio': 0.001953125, 'reward': 0.8670312166213989, 'reward_std': 0.36235228180885315, 'frac_reward_zero_std': 0.375, 'answer_exact_match': 0.85546875, 'format_exact_rate': 0.998046875, 'length_penalty_rate': 0.083984375, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.016488445922732353, 'sampling/importance_sampling_ratio/mean': 0.49117860198020935, 'epoch': 0.11}
#  18% 179/1000 [18:51<1:05:26,  4.78s/it]
# Greedy eval step 180:   0% 0/2 [00:00<?, ?it/s]
# Greedy eval step 180:  50% 1/2 [00:18<00:18, 18.55s/it]
# Greedy eval step 180: 100% 2/2 [00:43<00:00, 21.91s/it]
# {'loss': -0.0574, 'grad_norm': 0.1382988542318344, 'learning_rate': 1.8858031147626323e-06, 'kl': 0.008906304836273193, 'entropy': 0.259171299636364, 'clip_ratio/region_mean': 0.0, 'epoch': 0.11}
# {'loss': -0.0131, 'grad_norm': 0.16630122065544128, 'learning_rate': 1.8812524310525989e-06, 'kl': 0.009916271083056927, 'entropy': 0.26182736208041507, 'clip_ratio/region_mean': 0.0, 'epoch': 0.11}
# {'loss': -0.0043, 'grad_norm': 0.11520563811063766, 'learning_rate': 1.8766185526353477e-06, 'kl': 0.008040566773464283, 'entropy': 0.23058397074540457, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 98.18359375, 'completions/clipped_ratio': 0.0, 'reward': 0.8646875023841858, 'reward_std': 0.353733092546463, 'frac_reward_zero_std': 0.40625, 'answer_exact_match': 0.857421875, 'format_exact_rate': 0.998046875, 'length_penalty_rate': 0.126953125, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.015337279066443443, 'sampling/importance_sampling_ratio/mean': 0.46061211824417114, 'epoch': 0.11}
# {'loss': -0.0147, 'grad_norm': 0.09603764116764069, 'learning_rate': 1.871901916972547e-06, 'kl': 0.008301262355720004, 'entropy': 0.23332574466864267, 'clip_ratio/region_mean': 0.0, 'epoch': 0.12}
# {'loss': -0.0083, 'grad_norm': 0.14788512885570526, 'learning_rate': 1.867102969338569e-06, 'kl': 0.008464171007896462, 'entropy': 0.23939303308725357, 'clip_ratio/region_mean': 0.0, 'epoch': 0.12}
# {'loss': -0.0438, 'grad_norm': 0.16608849167823792, 'learning_rate': 1.8622221627784538e-06, 'completions/mean_length': 93.4609375, 'completions/clipped_ratio': 0.001953125, 'reward': 0.8712890148162842, 'reward_std': 0.3570918142795563, 'frac_reward_zero_std': 0.34375, 'answer_exact_match': 0.859375, 'format_exact_rate': 0.99609375, 'length_penalty_rate': 0.078125, 'parse_fail_rate': 0.001953125, 'sampling/sampling_logp_difference/mean': 0.016018399968743324, 'sampling/importance_sampling_ratio/mean': 0.5012068748474121, 'kl': 0.01128934370353818, 'entropy': 0.24087904890378317, 'clip_ratio/region_mean': 0.0, 'epoch': 0.12}
# {'loss': -0.0126, 'grad_norm': 0.12725262343883514, 'learning_rate': 1.8572599580651413e-06, 'kl': 0.01071789301931858, 'entropy': 0.2595292081435521, 'clip_ratio/region_mean': 0.0, 'epoch': 0.12}
#  20% 199/1000 [20:53<41:28,  3.11s/it]
# Greedy eval step 200:   0% 0/2 [00:00<?, ?it/s]
# Greedy eval step 200:  50% 1/2 [00:18<00:18, 18.54s/it]
# Greedy eval step 200: 100% 2/2 [00:35<00:00, 17.74s/it]
# {'loss': -0.0092, 'grad_norm': 0.11564017087221146, 'learning_rate': 1.8522168236559692e-06, 'kl': 0.011534191823254028, 'entropy': 0.22965383778015772, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 94.115234375, 'completions/clipped_ratio': 0.0, 'reward': 0.8431249856948853, 'reward_std': 0.37982746958732605, 'frac_reward_zero_std': 0.53125, 'answer_exact_match': 0.8359375, 'format_exact_rate': 0.994140625, 'length_penalty_rate': 0.126953125, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.016389768570661545, 'sampling/importance_sampling_ratio/mean': 0.4944491386413574, 'epoch': 0.12}
# {'loss': -0.0195, 'grad_norm': 0.05661872774362564, 'learning_rate': 1.8470932356484505e-06, 'kl': 0.010610732715576887, 'entropy': 0.23528329034646353, 'clip_ratio/region_mean': 0.0, 'epoch': 0.12}
# {'loss': -0.0109, 'grad_norm': 0.17475876212120056, 'learning_rate': 1.841889677735327e-06, 'kl': 0.010758529106775919, 'entropy': 0.2561441386739413, 'clip_ratio/region_mean': 0.0, 'epoch': 0.13}
# {'loss': -0.021, 'grad_norm': 0.12250275164842606, 'learning_rate': 1.8366066411589048e-06, 'kl': 0.011207133531570435, 'entropy': 0.26456119120121, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 106.626953125, 'completions/clipped_ratio': 0.00390625, 'reward': 0.752734363079071, 'reward_std': 0.44632914662361145, 'frac_reward_zero_std': 0.34375, 'answer_exact_match': 0.75390625, 'format_exact_rate': 0.99609375, 'length_penalty_rate': 0.2109375, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.016729291528463364, 'sampling/importance_sampling_ratio/mean': 0.41163986921310425, 'epoch': 0.13}
# {'loss': -0.0313, 'grad_norm': 0.08179664611816406, 'learning_rate': 1.8312446246646808e-06, 'kl': 0.010755407934387526, 'entropy': 0.25970915456612903, 'clip_ratio/region_mean': 0.0, 'epoch': 0.13}
# {'loss': -0.0349, 'grad_norm': 0.06950881332159042, 'learning_rate': 1.8258041344542563e-06, 'kl': 0.012125568774839243, 'entropy': 0.27220259606838226, 'clip_ratio/region_mean': 0.0, 'epoch': 0.13}
# {'loss': -0.0101, 'grad_norm': 0.10219798982143402, 'learning_rate': 1.8202856841375515e-06, 'completions/mean_length': 86.255859375, 'completions/clipped_ratio': 0.0, 'reward': 0.8543750047683716, 'reward_std': 0.3691503703594208, 'frac_reward_zero_std': 0.46875, 'answer_exact_match': 0.83984375, 'format_exact_rate': 1.0, 'length_penalty_rate': 0.0546875, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.014155660755932331, 'sampling/importance_sampling_ratio/mean': 0.545019268989563, 'kl': 0.011599448354293903, 'entropy': 0.21135364969571432, 'clip_ratio/region_mean': 0.0, 'epoch': 0.13}
#  22% 219/1000 [22:59<57:44,  4.44s/it]
# Greedy eval step 220:   0% 0/2 [00:00<?, ?it/s]
# Greedy eval step 220:  50% 1/2 [00:19<00:19, 19.22s/it]
# Greedy eval step 220: 100% 2/2 [00:43<00:00, 21.70s/it]
# {'loss': 0.0129, 'grad_norm': 0.21344681084156036, 'learning_rate': 1.814689794684316e-06, 'kl': 0.012984869225571552, 'entropy': 0.2096921131014824, 'clip_ratio/region_mean': 0.0, 'epoch': 0.14}
# {'loss': -0.0264, 'grad_norm': 0.04640008509159088, 'learning_rate': 1.8090169943749474e-06, 'kl': 0.012104526938249668, 'entropy': 0.22740895797808966, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 103.626953125, 'completions/clipped_ratio': 0.00390625, 'reward': 0.8765234351158142, 'reward_std': 0.3481946885585785, 'frac_reward_zero_std': 0.4375, 'answer_exact_match': 0.875, 'format_exact_rate': 0.994140625, 'length_penalty_rate': 0.181640625, 'parse_fail_rate': 0.001953125, 'sampling/sampling_logp_difference/mean': 0.015361865051090717, 'sampling/importance_sampling_ratio/mean': 0.4723033905029297, 'epoch': 0.14}
# {'loss': -0.0245, 'grad_norm': 0.07191239297389984, 'learning_rate': 1.8032678187506185e-06, 'kl': 0.010901989415287971, 'entropy': 0.22824962188800177, 'clip_ratio/region_mean': 0.0, 'epoch': 0.14}
# {'loss': -0.0015, 'grad_norm': 0.06861765682697296, 'learning_rate': 1.7974428105627206e-06, 'kl': 0.012540758897860846, 'entropy': 0.24216299007336298, 'clip_ratio/region_mean': 0.0, 'epoch': 0.14}
# {'loss': -0.0375, 'grad_norm': 0.052589062601327896, 'learning_rate': 1.7915425197216243e-06, 'kl': 0.012693145467589298, 'entropy': 0.22979711492856345, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 92.55078125, 'completions/clipped_ratio': 0.0, 'reward': 0.8986718654632568, 'reward_std': 0.3266310691833496, 'frac_reward_zero_std': 0.59375, 'answer_exact_match': 0.88671875, 'format_exact_rate': 0.998046875, 'length_penalty_rate': 0.080078125, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.014686298556625843, 'sampling/importance_sampling_ratio/mean': 0.5397508144378662, 'epoch': 0.14}
# {'loss': -0.0268, 'grad_norm': 0.07733463495969772, 'learning_rate': 1.7855675032447646e-06, 'kl': 0.012293115723878145, 'entropy': 0.21388675024112067, 'clip_ratio/region_mean': 0.0, 'epoch': 0.15}
#  24% 239/1000 [24:58<35:11,  2.77s/it]
# Greedy eval step 240:   0% 0/2 [00:00<?, ?it/s]
# Greedy eval step 240:  50% 1/2 [00:18<00:18, 18.80s/it]
# Greedy eval step 240: 100% 2/2 [00:43<00:00, 21.78s/it]
# {'loss': 0.0221, 'grad_norm': 0.15675678849220276, 'learning_rate': 1.7795183252040567e-06, 'kl': 0.012173540114114681, 'entropy': 0.2128235176205635, 'clip_ratio/region_mean': 0.0, 'epoch': 0.15}
# {'loss': -0.0228, 'grad_norm': 0.08970469981431961, 'learning_rate': 1.7733955566726437e-06, 'completions/mean_length': 93.591796875, 'completions/clipped_ratio': 0.0, 'reward': 0.8049218654632568, 'reward_std': 0.40920424461364746, 'frac_reward_zero_std': 0.40625, 'answer_exact_match': 0.80078125, 'format_exact_rate': 0.998046875, 'length_penalty_rate': 0.158203125, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.016690772026777267, 'sampling/importance_sampling_ratio/mean': 0.4976006746292114, 'kl': 0.011682640295475721, 'entropy': 0.25697170197963715, 'clip_ratio/region_mean': 0.0, 'epoch': 0.15}
# {'loss': 0.0052, 'grad_norm': 0.10076745599508286, 'learning_rate': 1.767199775670986e-06, 'kl': 0.013386591182400783, 'entropy': 0.2593515117963155, 'clip_ratio/region_mean': 0.0, 'epoch': 0.15}
# {'loss': -0.0403, 'grad_norm': 0.066118523478508, 'learning_rate': 1.7609315671122912e-06, 'kl': 0.01401958925028642, 'entropy': 0.26496294885873795, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 98.955078125, 'completions/clipped_ratio': 0.0, 'reward': 0.8892968893051147, 'reward_std': 0.33087602257728577, 'frac_reward_zero_std': 0.28125, 'answer_exact_match': 0.8828125, 'format_exact_rate': 0.998046875, 'length_penalty_rate': 0.134765625, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.015580014325678349, 'sampling/importance_sampling_ratio/mean': 0.4855359196662903, 'epoch': 0.15}
# {'loss': -0.0336, 'grad_norm': 0.0902097150683403, 'learning_rate': 1.7545915227472964e-06, 'kl': 0.01345193355033795, 'entropy': 0.23018026600281397, 'clip_ratio/region_mean': 0.0, 'epoch': 0.15}
# {'loss': -0.0243, 'grad_norm': 0.07301563024520874, 'learning_rate': 1.748180241108404e-06, 'kl': 0.01364215649664402, 'entropy': 0.22525407622257868, 'clip_ratio/region_mean': 0.0, 'epoch': 0.16}
# {'loss': -0.0382, 'grad_norm': 0.10129887610673904, 'learning_rate': 1.7416983274531774e-06, 'kl': 0.01282269631822904, 'entropy': 0.2127805401881536, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 93.931640625, 'completions/clipped_ratio': 0.0, 'reward': 0.9014452695846558, 'reward_std': 0.3179980516433716, 'frac_reward_zero_std': 0.375, 'answer_exact_match': 0.890625, 'format_exact_rate': 1.0, 'length_penalty_rate': 0.091796875, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.01385833416134119, 'sampling/importance_sampling_ratio/mean': 0.5308752059936523, 'epoch': 0.16}
#  26% 259/1000 [27:10<55:23,  4.49s/it]
# Greedy eval step 260:   0% 0/2 [00:00<?, ?it/s]
# Greedy eval step 260:  50% 1/2 [00:18<00:18, 18.87s/it]
# Greedy eval step 260: 100% 2/2 [00:35<00:00, 17.59s/it]
# {'loss': -0.0507, 'grad_norm': 0.13370566070079803, 'learning_rate': 1.7351463937072005e-06, 'kl': 0.013729331704477469, 'entropy': 0.20121172815561295, 'clip_ratio/region_mean': 0.0, 'epoch': 0.16}
# {'loss': -0.0031, 'grad_norm': 0.13937005400657654, 'learning_rate': 1.7285250584063097e-06, 'kl': 0.014141607253501812, 'entropy': 0.19802879045406976, 'clip_ratio/region_mean': 0.0, 'epoch': 0.16}
# {'loss': -0.0151, 'grad_norm': 0.06046787649393082, 'learning_rate': 1.721834946638202e-06, 'completions/mean_length': 89.228515625, 'completions/clipped_ratio': 0.0, 'reward': 0.8428515195846558, 'reward_std': 0.3818346858024597, 'frac_reward_zero_std': 0.5625, 'answer_exact_match': 0.833984375, 'format_exact_rate': 1.0, 'length_penalty_rate': 0.111328125, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.01639264076948166, 'sampling/importance_sampling_ratio/mean': 0.5232510566711426, 'kl': 0.015531510890771946, 'entropy': 0.23496645937363306, 'clip_ratio/region_mean': 0.0, 'epoch': 0.16}
# {'loss': -0.0249, 'grad_norm': 0.0759802907705307, 'learning_rate': 1.7150766899834204e-06, 'kl': 0.013321135503550371, 'entropy': 0.2399846613407135, 'clip_ratio/region_mean': 0.0, 'epoch': 0.17}
# {'loss': -0.0087, 'grad_norm': 0.09785530716180801, 'learning_rate': 1.708250926455733e-06, 'kl': 0.015138018876314163, 'entropy': 0.2394082248210907, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 92.59765625, 'completions/clipped_ratio': 0.0, 'reward': 0.8928515315055847, 'reward_std': 0.33408060669898987, 'frac_reward_zero_std': 0.59375, 'answer_exact_match': 0.87890625, 'format_exact_rate': 1.0, 'length_penalty_rate': 0.060546875, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.014133968390524387, 'sampling/importance_sampling_ratio/mean': 0.5283410549163818, 'epoch': 0.17}
# {'loss': 0.0001, 'grad_norm': 0.19776184856891632, 'learning_rate': 1.7013583004418993e-06, 'kl': 0.01349202978114287, 'entropy': 0.20503495385249457, 'clip_ratio/region_mean': 0.0, 'epoch': 0.17}
# {'loss': -0.0051, 'grad_norm': 0.11972501873970032, 'learning_rate': 1.6943994626408363e-06, 'kl': 0.015592531766742468, 'entropy': 0.1962027500073115, 'clip_ratio/region_mean': 0.0, 'epoch': 0.17}
#  28% 279/1000 [28:59<30:48,  2.56s/it]
# Greedy eval step 280:   0% 0/2 [00:00<?, ?it/s]
# Greedy eval step 280:  50% 1/2 [00:18<00:18, 18.40s/it]
# Greedy eval step 280: 100% 2/2 [00:40<00:00, 20.15s/it]
# {'loss': -0.0274, 'grad_norm': 0.11756166815757751, 'learning_rate': 1.6873750700021914e-06, 'kl': 0.015173602849245071, 'entropy': 0.22824498762687048, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 90.505859375, 'completions/clipped_ratio': 0.001953125, 'reward': 0.8733593225479126, 'reward_std': 0.3535224199295044, 'frac_reward_zero_std': 0.46875, 'answer_exact_match': 0.86328125, 'format_exact_rate': 0.9921875, 'length_penalty_rate': 0.09765625, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.015951592475175858, 'sampling/importance_sampling_ratio/mean': 0.5103437900543213, 'epoch': 0.17}
# {'loss': 0.0022, 'grad_norm': 0.1297372728586197, 'learning_rate': 1.6802857856643214e-06, 'kl': 0.014284423242012659, 'entropy': 0.2121619830528895, 'clip_ratio/region_mean': 0.0, 'epoch': 0.17}
# {'loss': -0.0302, 'grad_norm': 0.09250442683696747, 'learning_rate': 1.673132278891689e-06, 'kl': 0.012915045799066624, 'entropy': 0.24474324534336725, 'clip_ratio/region_mean': 0.0, 'epoch': 0.18}
# {'loss': -0.0245, 'grad_norm': 0.0959315076470375, 'learning_rate': 1.665915225011681e-06, 'completions/mean_length': 88.2890625, 'completions/clipped_ratio': 0.0, 'reward': 0.9014452695846558, 'reward_std': 0.3219732642173767, 'frac_reward_zero_std': 0.46875, 'answer_exact_match': 0.888671875, 'format_exact_rate': 1.0, 'length_penalty_rate': 0.072265625, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.015684541314840317, 'sampling/importance_sampling_ratio/mean': 0.5103931427001953, 'kl': 0.013561861279110113, 'entropy': 0.231671171883742, 'clip_ratio/region_mean': 0.0, 'epoch': 0.18}
# {'loss': -0.0325, 'grad_norm': 0.12080510705709457, 'learning_rate': 1.6586353053508545e-06, 'kl': 0.012108913622796535, 'entropy': 0.2322635700305303, 'clip_ratio/region_mean': 0.0, 'epoch': 0.18}
# {'loss': -0.0084, 'grad_norm': 0.08567103743553162, 'learning_rate': 1.651293207170615e-06, 'kl': 0.01277383416891098, 'entropy': 0.21743741631507874, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 97.91796875, 'completions/clipped_ratio': 0.00390625, 'reward': 0.8800390362739563, 'reward_std': 0.3422602415084839, 'frac_reward_zero_std': 0.40625, 'answer_exact_match': 0.875, 'format_exact_rate': 0.994140625, 'length_penalty_rate': 0.1484375, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.014890958555042744, 'sampling/importance_sampling_ratio/mean': 0.5094886422157288, 'epoch': 0.18}
#  30% 299/1000 [31:10<54:41,  4.68s/it]
# Greedy eval step 300:   0% 0/2 [00:00<?, ?it/s]
# Greedy eval step 300:  50% 1/2 [00:19<00:19, 19.64s/it]
# Greedy eval step 300: 100% 2/2 [00:41<00:00, 20.67s/it]
# {'loss': -0.0509, 'grad_norm': 0.06948449462652206, 'learning_rate': 1.6438896236023374e-06, 'kl': 0.012403423277040323, 'entropy': 0.20428248246510824, 'clip_ratio/region_mean': 0.0, 'epoch': 0.18}
# {'loss': 0.0073, 'grad_norm': 0.0908280462026596, 'learning_rate': 1.636425253581928e-06, 'kl': 0.013227305219819149, 'entropy': 0.22235071659088135, 'clip_ratio/region_mean': 0.0, 'epoch': 0.19}
# {'loss': -0.0213, 'grad_norm': 0.052758846431970596, 'learning_rate': 1.6289008017838443e-06, 'kl': 0.015532705777635178, 'entropy': 0.22065803905328116, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 95.03515625, 'completions/clipped_ratio': 0.0, 'reward': 0.8811327815055847, 'reward_std': 0.3419082462787628, 'frac_reward_zero_std': 0.53125, 'answer_exact_match': 0.873046875, 'format_exact_rate': 1.0, 'length_penalty_rate': 0.119140625, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.015009201131761074, 'sampling/importance_sampling_ratio/mean': 0.5211981534957886, 'epoch': 0.19}
# {'loss': -0.0209, 'grad_norm': 0.07925538718700409, 'learning_rate': 1.6213169785545686e-06, 'kl': 0.015935140351454418, 'entropy': 0.22201758871475855, 'clip_ratio/region_mean': 0.0, 'epoch': 0.19}
# {'loss': 0.0209, 'grad_norm': 0.14438396692276, 'learning_rate': 1.6136744998455473e-06, 'kl': 0.01534935940677921, 'entropy': 0.22307984034220377, 'clip_ratio/region_mean': 0.0, 'epoch': 0.19}
# {'loss': -0.031, 'grad_norm': 0.08660469949245453, 'learning_rate': 1.6059740871456034e-06, 'completions/mean_length': 90.27734375, 'completions/clipped_ratio': 0.00390625, 'reward': 0.8241406083106995, 'reward_std': 0.4019834101200104, 'frac_reward_zero_std': 0.4375, 'answer_exact_match': 0.8125, 'format_exact_rate': 0.9921875, 'length_penalty_rate': 0.080078125, 'parse_fail_rate': 0.001953125, 'sampling/sampling_logp_difference/mean': 0.01664285734295845, 'sampling/importance_sampling_ratio/mean': 0.49197661876678467, 'kl': 0.01646673136080305, 'entropy': 0.25605681041876477, 'clip_ratio/region_mean': 0.0, 'epoch': 0.19}
# {'loss': -0.0158, 'grad_norm': 0.161197692155838, 'learning_rate': 1.5982164674128218e-06, 'kl': 0.015776867978274822, 'entropy': 0.2642829070488612, 'clip_ratio/region_mean': 0.0, 'epoch': 0.19}
#  32% 319/1000 [33:19<39:27,  3.48s/it]
# Greedy eval step 320:   0% 0/2 [00:00<?, ?it/s]
# Greedy eval step 320:  50% 1/2 [00:21<00:21, 21.35s/it]
# Greedy eval step 320: 100% 2/2 [00:46<00:00, 23.31s/it]
# ...
# {'loss': -0.0241, 'grad_norm': 0.1184922456741333, 'learning_rate': 6.974738833861382e-08, 'kl': 0.03157889749854803, 'entropy': 0.19448439280192056, 'clip_ratio/region_mean': 0.0, 'epoch': 0.54}
# {'loss': -0.0397, 'grad_norm': 0.10769042372703552, 'learning_rate': 6.622626517355556e-08, 'kl': 0.029828106984496117, 'entropy': 0.2168167307972908, 'clip_ratio/region_mean': 0.0, 'epoch': 0.54}
# {'loss': -0.0518, 'grad_norm': 0.11380113661289215, 'learning_rate': 6.279329499365649e-08, 'completions/mean_length': 92.5078125, 'completions/clipped_ratio': 0.0, 'reward': 0.9131640195846558, 'reward_std': 0.30206745862960815, 'frac_reward_zero_std': 0.5, 'answer_exact_match': 0.90234375, 'format_exact_rate': 1.0, 'length_penalty_rate': 0.091796875, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.012223507277667522, 'sampling/importance_sampling_ratio/mean': 0.6293813586235046, 'kl': 0.02935083645085494, 'entropy': 0.16058908154567084, 'clip_ratio/region_mean': 0.0, 'epoch': 0.55}
# {'loss': -0.008, 'grad_norm': 0.20420192182064056, 'learning_rate': 5.944880188874479e-08, 'kl': 0.026879835563401382, 'entropy': 0.1644813840587934, 'clip_ratio/region_mean': 0.0, 'epoch': 0.55}
# {'loss': -0.038, 'grad_norm': 0.11632659286260605, 'learning_rate': 5.6193101595963575e-08, 'kl': 0.027484599500894547, 'entropy': 0.1595893328388532, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 101.94921875, 'completions/clipped_ratio': 0.001953125, 'reward': 0.8546874523162842, 'reward_std': 0.37079471349716187, 'frac_reward_zero_std': 0.4375, 'answer_exact_match': 0.853515625, 'format_exact_rate': 0.99609375, 'length_penalty_rate': 0.1875, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.013015982694923878, 'sampling/importance_sampling_ratio/mean': 0.5752053260803223, 'epoch': 0.55}
#  90% 899/1000 [1:34:09<08:10,  4.86s/it]
# Greedy eval step 900:   0% 0/2 [00:00<?, ?it/s]
# Greedy eval step 900:  50% 1/2 [00:22<00:22, 22.78s/it]
# Greedy eval step 900: 100% 2/2 [00:47<00:00, 23.85s/it]
# {'loss': -0.0381, 'grad_norm': 0.07828478515148163, 'learning_rate': 5.302650146996279e-08, 'kl': 0.029542814940214157, 'entropy': 0.15747622400522232, 'clip_ratio/region_mean': 0.0, 'epoch': 0.55}
# {'loss': 0.0044, 'grad_norm': 0.11362562328577042, 'learning_rate': 4.994930045388412e-08, 'kl': 0.030897157887617748, 'entropy': 0.17248435566822687, 'clip_ratio/region_mean': 0.0, 'epoch': 0.55}
# {'loss': -0.0154, 'grad_norm': 0.15749654173851013, 'learning_rate': 4.696178905113912e-08, 'kl': 0.026013436416784923, 'entropy': 0.17001203944285712, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 98.52734375, 'completions/clipped_ratio': 0.0, 'reward': 0.9189842939376831, 'reward_std': 0.29138267040252686, 'frac_reward_zero_std': 0.40625, 'answer_exact_match': 0.91015625, 'format_exact_rate': 0.998046875, 'length_penalty_rate': 0.111328125, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.013137422502040863, 'sampling/importance_sampling_ratio/mean': 0.5904326438903809, 'epoch': 0.56}
# {'loss': 0.0015, 'grad_norm': 0.11417270451784134, 'learning_rate': 4.406424929798403e-08, 'kl': 0.02690568007528782, 'entropy': 0.17951754480600357, 'clip_ratio/region_mean': 0.0, 'epoch': 0.56}
# {'loss': -0.0483, 'grad_norm': 0.11308752000331879, 'learning_rate': 4.1256954736894056e-08, 'kl': 0.026133529531459015, 'entropy': 0.16328414529561996, 'clip_ratio/region_mean': 0.0, 'epoch': 0.56}
# {'loss': -0.0373, 'grad_norm': 0.10911082476377487, 'learning_rate': 3.854017039074009e-08, 'completions/mean_length': 96.189453125, 'completions/clipped_ratio': 0.0, 'reward': 0.8848437070846558, 'reward_std': 0.3437083065509796, 'frac_reward_zero_std': 0.4375, 'answer_exact_match': 0.875, 'format_exact_rate': 1.0, 'length_penalty_rate': 0.1015625, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.01327428873628378, 'sampling/importance_sampling_ratio/mean': 0.5909167528152466, 'kl': 0.025642942326764267, 'entropy': 0.18517852822939554, 'clip_ratio/region_mean': 0.0, 'epoch': 0.56}
# {'loss': -0.0068, 'grad_norm': 0.08663863688707352, 'learning_rate': 3.5914152737768545e-08, 'kl': 0.02673533217360576, 'entropy': 0.17688826471567154, 'clip_ratio/region_mean': 0.0, 'epoch': 0.56}
#  92% 919/1000 [1:36:12<03:48,  2.83s/it]
# Greedy eval step 920:   0% 0/2 [00:00<?, ?it/s]
# Greedy eval step 920:  50% 1/2 [00:23<00:23, 23.05s/it]
# Greedy eval step 920: 100% 2/2 [00:47<00:00, 23.98s/it]
# {'loss': -0.036, 'grad_norm': 0.14706215262413025, 'learning_rate': 3.3379149687388864e-08, 'kl': 0.025515919240812462, 'entropy': 0.17759556074937186, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 86.73046875, 'completions/clipped_ratio': 0.0078125, 'reward': 0.8784375190734863, 'reward_std': 0.3546094298362732, 'frac_reward_zero_std': 0.625, 'answer_exact_match': 0.865234375, 'format_exact_rate': 0.9921875, 'length_penalty_rate': 0.06640625, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.014227294363081455, 'sampling/importance_sampling_ratio/mean': 0.6374082565307617, 'epoch': 0.56}
# {'loss': -0.0025, 'grad_norm': 0.06771229952573776, 'learning_rate': 3.093540055676957e-08, 'kl': 0.0283503873894612, 'entropy': 0.21125340213378271, 'clip_ratio/region_mean': 0.0, 'epoch': 0.57}
# {'loss': -0.0106, 'grad_norm': 0.043227095156908035, 'learning_rate': 2.8583136048245692e-08, 'kl': 0.02690149253855149, 'entropy': 0.16992894808451334, 'clip_ratio/region_mean': 0.0, 'epoch': 0.57}
# {'loss': -0.0432, 'grad_norm': 0.21565057337284088, 'learning_rate': 2.6322578227538806e-08, 'kl': 0.025562179895738762, 'entropy': 0.18252248813708624, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 98.376953125, 'completions/clipped_ratio': 0.0, 'reward': 0.8754687309265137, 'reward_std': 0.34523507952690125, 'frac_reward_zero_std': 0.3125, 'answer_exact_match': 0.8671875, 'format_exact_rate': 1.0, 'length_penalty_rate': 0.1171875, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.014235691167414188, 'sampling/importance_sampling_ratio/mean': 0.5448455810546875, 'epoch': 0.57}
# {'loss': -0.0234, 'grad_norm': 0.11413641273975372, 'learning_rate': 2.415394050279318e-08, 'kl': 0.02405164483934641, 'entropy': 0.19241711497306824, 'clip_ratio/region_mean': 0.0, 'epoch': 0.57}
# {'loss': -0.024, 'grad_norm': 0.35219210386276245, 'learning_rate': 2.2077427604429433e-08, 'kl': 0.025658613070845604, 'entropy': 0.18623711913824081, 'clip_ratio/region_mean': 0.0, 'epoch': 0.57}
# {'loss': -0.0163, 'grad_norm': 0.10220809280872345, 'learning_rate': 2.009323556581566e-08, 'completions/mean_length': 99.021484375, 'completions/clipped_ratio': 0.0, 'reward': 0.8055468201637268, 'reward_std': 0.4148256480693817, 'frac_reward_zero_std': 0.4375, 'answer_exact_match': 0.798828125, 'format_exact_rate': 1.0, 'length_penalty_rate': 0.1328125, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.014717564918100834, 'sampling/importance_sampling_ratio/mean': 0.5387542247772217, 'kl': 0.028310667102535565, 'entropy': 0.21935888131459555, 'clip_ratio/region_mean': 0.0, 'epoch': 0.58}
#  94% 939/1000 [1:38:30<04:46,  4.70s/it]
# Greedy eval step 940:   0% 0/2 [00:00<?, ?it/s]
# Greedy eval step 940:  50% 1/2 [00:22<00:22, 22.99s/it]
# Greedy eval step 940: 100% 2/2 [00:46<00:00, 23.08s/it]
# {'loss': 0.01, 'grad_norm': 0.0993216335773468, 'learning_rate': 1.8201551704762453e-08, 'kl': 0.025841451560457546, 'entropy': 0.19298837830622992, 'clip_ratio/region_mean': 0.0, 'epoch': 0.58}
# {'loss': -0.025, 'grad_norm': 0.1305045187473297, 'learning_rate': 1.640255460583817e-08, 'kl': 0.02592185450096925, 'entropy': 0.18353183815876642, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 92.345703125, 'completions/clipped_ratio': 0.0, 'reward': 0.9010546207427979, 'reward_std': 0.326117604970932, 'frac_reward_zero_std': 0.53125, 'answer_exact_match': 0.892578125, 'format_exact_rate': 1.0, 'length_penalty_rate': 0.115234375, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.013176015578210354, 'sampling/importance_sampling_ratio/mean': 0.6241458058357239, 'epoch': 0.58}
# {'loss': 0.0173, 'grad_norm': 0.2380070835351944, 'learning_rate': 1.4696414103509636e-08, 'kl': 0.02916382656743129, 'entropy': 0.15835986783107123, 'clip_ratio/region_mean': 0.0, 'epoch': 0.58}
# {'loss': -0.0494, 'grad_norm': 0.06018500402569771, 'learning_rate': 1.3083291266109298e-08, 'kl': 0.02867149127026399, 'entropy': 0.16272949427366257, 'clip_ratio/region_mean': 0.0, 'epoch': 0.58}
# {'loss': 0.0229, 'grad_norm': 0.11397967487573624, 'learning_rate': 1.1563338380629617e-08, 'kl': 0.025986356660723686, 'entropy': 0.14614331473906836, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 89.20703125, 'completions/clipped_ratio': 0.0, 'reward': 0.947265625, 'reward_std': 0.24850302934646606, 'frac_reward_zero_std': 0.46875, 'answer_exact_match': 0.935546875, 'format_exact_rate': 0.99609375, 'length_penalty_rate': 0.08203125, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.011863655410706997, 'sampling/importance_sampling_ratio/mean': 0.6498483419418335, 'epoch': 0.58}
# {'loss': -0.0229, 'grad_norm': 0.13244637846946716, 'learning_rate': 1.013669893834601e-08, 'kl': 0.024781728473802406, 'entropy': 0.14134171977639198, 'clip_ratio/region_mean': 0.0, 'epoch': 0.59}
#  96% 959/1000 [1:40:22<01:40,  2.44s/it]
# Greedy eval step 960:   0% 0/2 [00:00<?, ?it/s]
# Greedy eval step 960:  50% 1/2 [00:22<00:22, 22.74s/it]
# Greedy eval step 960: 100% 2/2 [00:47<00:00, 23.51s/it]
# {'loss': -0.0462, 'grad_norm': 0.09215381741523743, 'learning_rate': 8.803507621270578e-09, 'kl': 0.02381964462498824, 'entropy': 0.13822086403767267, 'clip_ratio/region_mean': 0.0, 'epoch': 0.59}
# {'loss': -0.0216, 'grad_norm': 0.09574607759714127, 'learning_rate': 7.563890289437824e-09, 'completions/mean_length': 89.5234375, 'completions/clipped_ratio': 0.0, 'reward': 0.9336718320846558, 'reward_std': 0.2729282081127167, 'frac_reward_zero_std': 0.5, 'answer_exact_match': 0.923828125, 'format_exact_rate': 0.990234375, 'length_penalty_rate': 0.099609375, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.013609652407467365, 'sampling/importance_sampling_ratio/mean': 0.5971263647079468, 'kl': 0.031963505782186985, 'entropy': 0.17105098565419516, 'clip_ratio/region_mean': 0.0, 'epoch': 0.59}
# {'loss': -0.0367, 'grad_norm': 0.08678369224071503, 'learning_rate': 6.417963969022389e-09, 'kl': 0.033376993921895824, 'entropy': 0.1882331594824791, 'clip_ratio/region_mean': 0.0, 'epoch': 0.59}
# {'loss': -0.0171, 'grad_norm': 0.15023882687091827, 'learning_rate': 5.3658368412914375e-09, 'kl': 0.03219993319362402, 'entropy': 0.16131806870301565, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 92.802734375, 'completions/clipped_ratio': 0.0, 'reward': 0.8057421445846558, 'reward_std': 0.41561007499694824, 'frac_reward_zero_std': 0.46875, 'answer_exact_match': 0.79296875, 'format_exact_rate': 1.0, 'length_penalty_rate': 0.072265625, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.01395477820187807, 'sampling/importance_sampling_ratio/mean': 0.5909565091133118, 'epoch': 0.59}
# {'loss': 0.0132, 'grad_norm': 0.26626884937286377, 'learning_rate': 4.4076082323920575e-09, 'kl': 0.030600869407256443, 'entropy': 0.18841668715079626, 'clip_ratio/region_mean': 0.0, 'epoch': 0.6}
# {'loss': -0.0285, 'grad_norm': 0.07840052992105484, 'learning_rate': 3.543368603973529e-09, 'kl': 0.031249723707636196, 'entropy': 0.1918467159072558, 'clip_ratio/region_mean': 0.0, 'epoch': 0.6}
# {'loss': -0.0299, 'grad_norm': 0.14399488270282745, 'learning_rate': 2.773199544648164e-09, 'kl': 0.031493855019410454, 'entropy': 0.19289600104093552, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 89.31640625, 'completions/clipped_ratio': 0.0, 'reward': 0.8700000047683716, 'reward_std': 0.3592773675918579, 'frac_reward_zero_std': 0.5, 'answer_exact_match': 0.859375, 'format_exact_rate': 1.0, 'length_penalty_rate': 0.09375, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.01384938508272171, 'sampling/importance_sampling_ratio/mean': 0.5862619876861572, 'epoch': 0.6}
#  98% 979/1000 [1:42:40<01:45,  5.04s/it]
# Greedy eval step 980:   0% 0/2 [00:00<?, ?it/s]
# Greedy eval step 980:  50% 1/2 [00:23<00:23, 23.01s/it]
# Greedy eval step 980: 100% 2/2 [00:48<00:00, 24.14s/it]
# {'loss': -0.0012, 'grad_norm': 0.20814895629882812, 'learning_rate': 2.0971737622883512e-09, 'kl': 0.03039227208743493, 'entropy': 0.18824679404497147, 'clip_ratio/region_mean': 0.0, 'epoch': 0.6}
# {'loss': -0.0083, 'grad_norm': 0.14213933050632477, 'learning_rate': 1.5153550771630497e-09, 'kl': 0.02915843389928341, 'entropy': 0.1936714251836141, 'clip_ratio/region_mean': 0.0, 'epoch': 0.6}
# {'loss': -0.0249, 'grad_norm': 0.0925731435418129, 'learning_rate': 1.0277984159122733e-09, 'completions/mean_length': 95.791015625, 'completions/clipped_ratio': 0.005859375, 'reward': 0.8956640362739563, 'reward_std': 0.32741042971611023, 'frac_reward_zero_std': 0.5, 'answer_exact_match': 0.88671875, 'format_exact_rate': 0.994140625, 'length_penalty_rate': 0.109375, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.015462777577340603, 'sampling/importance_sampling_ratio/mean': 0.5435410737991333, 'kl': 0.031340984317163624, 'entropy': 0.19608813524246216, 'clip_ratio/region_mean': 0.0, 'epoch': 0.6}
# {'loss': -0.0131, 'grad_norm': 0.15695151686668396, 'learning_rate': 6.34549806362239e-10, 'kl': 0.030333939318855602, 'entropy': 0.23244095096985498, 'clip_ratio/region_mean': 0.0, 'epoch': 0.61}
# {'loss': -0.0081, 'grad_norm': 0.12119853496551514, 'learning_rate': 3.3564637317984315e-10, 'kl': 0.026201301875213783, 'entropy': 0.2137640416622162, 'clip_ratio/region_mean': 0.0, 'completions/mean_length': 96.12109375, 'completions/clipped_ratio': 0.0, 'reward': 0.9287499785423279, 'reward_std': 0.2798210382461548, 'frac_reward_zero_std': 0.40625, 'answer_exact_match': 0.91796875, 'format_exact_rate': 0.998046875, 'length_penalty_rate': 0.091796875, 'parse_fail_rate': 0.0, 'sampling/sampling_logp_difference/mean': 0.012448235414922237, 'sampling/importance_sampling_ratio/mean': 0.5996056795120239, 'epoch': 0.61}
# {'loss': -0.0263, 'grad_norm': 0.20248264074325562, 'learning_rate': 1.311163343677979e-10, 'kl': 0.027955906776090462, 'entropy': 0.14506903290748596, 'clip_ratio/region_mean': 0.0, 'epoch': 0.61}
# {'loss': -0.0329, 'grad_norm': 0.11602482199668884, 'learning_rate': 2.0978998601206555e-11, 'kl': 0.023122315915922325, 'entropy': 0.14883079628149667, 'clip_ratio/region_mean': 0.0, 'epoch': 0.61}
# 100% 999/1000 [1:44:46<00:02,  2.69s/it]
# Greedy eval step 1000:   0% 0/2 [00:00<?, ?it/s]
# Greedy eval step 1000:  50% 1/2 [00:20<00:20, 20.76s/it]
# Greedy eval step 1000: 100% 2/2 [00:46<00:00, 23.00s/it]
# {'kl': 0.02479484397917986, 'entropy': 0.1648217812180519, 'clip_ratio/region_mean': 0.0, 'epoch': 0.61}
# 100% 1000/1000 [1:45:34<00:00,  6.33s/it]
# {
#   "global_step": 1000,
#   "train_metrics": {
#     "train_runtime": 6337.7368,
#     "train_samples_per_second": 10.098,
#     "train_steps_per_second": 0.158,
#     "total_flos": 0.0,
#     "train_loss": -0.016840201055165382
#   },
#   "best_step": 980,
#   "best_metric": 0.895172,
#   "best_metric_name": "sft_val/exact_match"
# }
# swanlab: Experiment qwen25_3b_instruct_sft_gspo_g16 has completed
# swanlab: 🏠 View project at https://swanlab.cn/@jerryjsjsj/gsm8k-grpo
# swanlab: 🚀 View run at
# https://swanlab.cn/@jerryjsjsj/gsm8k-grpo/runs/k4pn6ix5vuj10x0npedwv
# [rank0]:[W505 01:49:10.448990530 ProcessGroupNCCL.cpp:1553] Warning: WARNING: destroy_process_group() was not called before program exit, which can leak resources. For more info, please see https://pytorch.org/docs/stable/distributed.html#shutdown (function operator())

# %% [markdown]
# ## Inspect outputs

# %%
import json
import sys
from pathlib import Path

COMMON_SRC = PROJECT_DIR / 'RL_common/src'
if str(COMMON_SRC) not in sys.path:
    sys.path.insert(0, str(COMMON_SRC))

from rl_common.config import format_run_name, load_config, make_run_dir

cfg = load_config(str(ACTIVE_CONFIG))
cfg['run']['resolved_name'] = format_run_name(cfg['run']['name'], cfg)
run_dir = make_run_dir(cfg['run']['output_root'], cfg['run']['resolved_name'])
print('run_dir =', run_dir)
# !find "{run_dir}" -maxdepth 2 -type f | sort

summary_path = run_dir / 'train_summary.json'
if summary_path.exists():
    print(summary_path.read_text(encoding='utf-8'))

best_path = run_dir / 'best_eval_results.json'
if best_path.exists():
    data = json.loads(best_path.read_text(encoding='utf-8'))
    print(json.dumps(data['summary'], indent=2, ensure_ascii=False))
# Out:
# run_dir = /content/drive/MyDrive/HPML_project/RL_GRPO_train/outputs/qwen25_3b_instruct_sft_gspo_g16_trainall
# /content/drive/MyDrive/HPML_project/RL_GRPO_train/outputs/qwen25_3b_instruct_sft_gspo_g16_trainall/best_eval_results.json
# /content/drive/MyDrive/HPML_project/RL_GRPO_train/outputs/qwen25_3b_instruct_sft_gspo_g16_trainall/final_adapter/adapter_config.json
# /content/drive/MyDrive/HPML_project/RL_GRPO_train/outputs/qwen25_3b_instruct_sft_gspo_g16_trainall/final_adapter/adapter_model.safetensors
# /content/drive/MyDrive/HPML_project/RL_GRPO_train/outputs/qwen25_3b_instruct_sft_gspo_g16_trainall/final_adapter/README.md
# /content/drive/MyDrive/HPML_project/RL_GRPO_train/outputs/qwen25_3b_instruct_sft_gspo_g16_trainall/latest_eval_results.json
# /content/drive/MyDrive/HPML_project/RL_GRPO_train/outputs/qwen25_3b_instruct_sft_gspo_g16_trainall/resolved_config.yaml
# /content/drive/MyDrive/HPML_project/RL_GRPO_train/outputs/qwen25_3b_instruct_sft_gspo_g16_trainall/train_summary.json
# {
#   "global_step": 1000,
#   "train_metrics": {
#     "train_runtime": 6337.7368,
#     "train_samples_per_second": 10.098,
#     "train_steps_per_second": 0.158,
#     "total_flos": 0.0,
#     "train_loss": -0.016840201055165382
#   },
#   "best_step": 980,
#   "best_metric": 0.895172,
#   "best_metric_name": "sft_val/exact_match"
# }
#
# {
#   "total": 725,
#   "correct": 649,
#   "exact_match": 0.895172,
#   "parse_success_rate": 1.0,
#   "format_exact_rate": 0.997241,
#   "length_penalty_rate": 0.08,
#   "reward_mean": 0.907117,
#   "reward_std": 0.313887,
#   "answer_reward_mean": 0.895172,
#   "format_reward_mean": 0.019945,
#   "penalty_mean": -0.008,
#   "avg_output_tokens": 89.925517,
#   "avg_output_tokens_correct": 86.744222,
#   "avg_output_tokens_wrong": 117.092105,
#   "total_latency_s": 48.283239,
#   "samples_per_second": 15.015563,
#   "tokens_per_second": 1350.28223,
#   "step": 980,
#   "best_metric": 0.895172,
#   "best_exact_match": 0.895172,
#   "best_step": 980
# }

# %% [markdown]
# ## Optional final eval on official GSM8K test

# %%
RUN_FINAL_TEST = True

if RUN_FINAL_TEST:
    cfg = load_config(str(ACTIVE_CONFIG))
    cfg['run']['resolved_name'] = format_run_name(cfg['run']['name'], cfg)
    train_run_dir = make_run_dir(cfg['run']['output_root'], cfg['run']['resolved_name'])
    final_adapter = train_run_dir / 'final_adapter'
    if not final_adapter.exists():
        raise FileNotFoundError(f'Missing final adapter: {final_adapter}')

    cfg['model']['adapter_path'] = str(final_adapter)
    cfg['model']['tokenizer_name_or_path'] = cfg['model']['base_model_name_or_path']
    cfg['run']['name'] = cfg['run']['resolved_name'] + '_final_test'
    cfg['eval']['max_new_tokens'] = 256
    cfg['eval']['batch_size'] = 512

    eval_cfg = Path('/content/gspo_final_eval.yaml')
    eval_cfg.write_text(yaml.safe_dump(cfg, sort_keys=False, allow_unicode=True), encoding='utf-8')
    print(eval_cfg.read_text(encoding='utf-8')[:1500])
    # !python RL_GRPO_train/train_grpo.py --config "{eval_cfg}" --eval-only --final-test
# Out:
# run:
#   name: qwen25_3b_instruct_sft_gspo_g16_trainall_final_test
#   output_root: RL_GRPO_train/outputs
#   resolved_name: qwen25_3b_instruct_sft_gspo_g16_trainall
# model:
#   base_model_name_or_path: Qwen/Qwen2.5-3B-Instruct
#   adapter_path: /content/drive/MyDrive/HPML_project/RL_GRPO_train/outputs/qwen25_3b_instruct_sft_gspo_g16_trainall/final_adapter
#   tokenizer_name_or_path: Qwen/Qwen2.5-3B-Instruct
#   trust_remote_code: true
#   prompt_template: qwen_chat
#   system_prompt: ''
#   include_empty_system: false
#   dtype: bf16
#   device_map: null
#   load_in_4bit: false
#   is_trainable_adapter: true
# train_dataset:
#   kind: sft_train
#   name: openai/gsm8k
#   config: main
#   path: SFT_train/data/gsm8k_sft_train.json
#   limit: null
# eval_dataset:
#   kind: sft_val
#   name: openai/gsm8k
#   config: main
#   path: SFT_train/data/gsm8k_sft_val.json
#   limit: 725
# final_eval_dataset:
#   kind: gsm8k_test
#   name: openai/gsm8k
#   config: main
#   start_index: 0
#   limit: null
# reward:
#   answer_correct: 1.0
#   answer_incorrect: 0.0
#   format_reward: 0.02
#   parse_fail_penalty: -0.1
#   length_penalty: -0.1
#   min_completion_tokens: 20
#   max_completion_tokens: 130
# eval:
#   every_steps: 20
#   batch_size: 512
#   max_prompt_length: 512
#   max_new_tokens: 256
#   metric_for_best: exact_match
# grpo:
#   per_device_train_batch_size: 32
#   num_generations: 16
#   generation_batch_size: 512
#   gradient_accumulation_steps: 2
#   temperature: 1.0
#   top_p: 0.95
#   learning_rate: 2.0e-06
#   lr_scheduler_type: cosine
#   max_prompt_length: 512
#   max_completion_len
# 2026-05-05 01:51:06.985786: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-05 01:51:07.038082: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards: 100% 2/2 [00:00<00:00, 75.87it/s]
# eval device = cuda:0
# Evaluating:   0% 0/3 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating: 100% 3/3 [01:21<00:00, 27.07s/it]
# {
#   "total": 1319,
#   "correct": 1062,
#   "exact_match": 0.805155,
#   "parse_success_rate": 1.0,
#   "format_exact_rate": 0.996209,
#   "length_penalty_rate": 0.115997,
#   "reward_mean": 0.81348,
#   "reward_std": 0.405695,
#   "answer_reward_mean": 0.805155,
#   "format_reward_mean": 0.019924,
#   "penalty_mean": -0.0116,
#   "avg_output_tokens": 93.426839,
#   "avg_output_tokens_correct": 87.887947,
#   "avg_output_tokens_wrong": 116.315175,
#   "total_latency_s": 81.221424,
#   "samples_per_second": 16.239558,
#   "tokens_per_second": 1517.210524
# }
