# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/HPML_project/RL_dryrun_rollout
# Out:
# /content/drive/MyDrive/HPML_project/RL_dryrun_rollout

# %%
# !pip install -e ../RL_common
# !pip uninstall -y torchao
# Out:
# Obtaining file:///content/drive/MyDrive/HPML_project/RL_common
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.0/529.0 kB 23.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 53.5 MB/s eta 0:00:00:00:0100:01
# ...
#   Building editable for rl-common (pyproject.toml) ... done
#   Created wheel for rl-common: filename=rl_common-0.1.0-0.editable-py3-none-any.whl size=1335 sha256=60b92f5233c0adf20b24188045892fc88877a900b77b9de3e4d4589266fe2ddc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xeygfe_k/wheels/84/60/07/b2193c8cbf231f53b0a9492f549226f9c6db67745f28015cb5
# Successfully built rl-common
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
# ...

# %%
# !python run_rollout.py \
  --config configs/qwen25_3b_sft_dryrun.yaml
# Out:
# Loading dataset: gsm8k_train_subset
# ...
# Loaded 200 prompts
# Loading tokenizer: SFT_train/outputs/qwen25_3b_gsm8k_lora_sft_full
# Loading model: Qwen/Qwen2.5-3B-Instruct
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 434/434 [00:01<00:00, 278.42it/s, Materializing param=model.norm.weight]
# Sampling rollouts: 100% 7/7 [05:07<00:00, 43.90s/it]
# {
#   "prompt_count": 200,
#   "completion_count": 3200,
#   "all_correct_rate": 0.37,
#   "all_wrong_rate": 0.015,
#   "mixed_rate": 0.615,
#   "parse_fail_rate": 0.0,
#   "eos_stop_rate": 0.999062,
#   "avg_completion_length": 95.86125,
#   "reward_distribution": {
#     "mean": 0.891984,
#     "std": 0.406356,
#     "min": -0.05,
#     "max": 1.1
#   }
# }
# Wrote rollout outputs to /content/drive/MyDrive/HPML_project/RL_dryrun_rollout/outputs/qwen25_3b_instruct_sft_dryrun_g16_train200
